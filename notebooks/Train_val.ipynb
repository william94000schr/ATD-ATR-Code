# %%
import torch
torch.cuda.empty_cache()
from google.colab import userdata
your_key = userdata.get('PIE_Colab')
# Out:
# ---------------------------------------------------------------------------
# SecretNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_173/721085079.py in <cell line: 0>()
#       2 torch.cuda.empty_cache()
#       3 from google.colab import userdata
# ----> 4 your_key = userdata.get('PIE_Colab')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/userdata.py in get(key)
#      66     raise TimeoutException(key)
#      67   if not resp.get('exists', False):
# ---> 68     raise SecretNotFoundError(key)
#      69   if not resp.get('access', False):
#      70     raise NotebookAccessError(key)
#
# SecretNotFoundError: Secret PIE_Colab does not exist.

# %%
# !git clone https://{your_key}@github.com/william94000schr/ATR_SAR.git
# Out:
# Cloning into 'ATR_SAR'...
# remote: Enumerating objects: 278, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 278 (delta 20), reused 26 (delta 10), pack-reused 240 (from 1)
# Receiving objects: 100% (278/278), 38.45 KiB | 4.81 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Dataset/PIE/Détection_Coco/SOC_40classes_coco.tar /content/
#!cp /content/drive/MyDrive/Dataset/PIE/MSTAR_coco.tar /content/
#!cp /content/drive/MyDrive/ISAE/3A/PIE/Détection_Coco_newClasses/SOC_50classes_coco.tar /content/
# !tar -xf /content/SOC_40classes_coco.tar -C /content/ATR_SAR/data/ --strip-components=1
#!tar -xf /content/MSTAR_coco.tar -C /content/ATR_SAR/data/ --strip-components=1

# %%
# %cd ATR_SAR/src/
# Out:
# /content/ATR_SAR/src

# %%
# !python train_val.py \
  --num_classes 40 \
  --num_epochs 10 \
  --proportion 0.50

#!python train.py \
  #--num_classes 10 \
  #--num_epochs 10 \
  #--proportion 1.0
# Out:
# Using device: cuda
# loading annotations into memory...
# Done (t=0.28s)
# creating index...
# index created!
# Dataset sizes - Train: 27236, Val: 6809
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100% 167M/167M [00:01<00:00, 174MB/s]
# Using AMP: True
#
# ...
# Epoch 1/10
# ...
# Train Epoch 0: 100% 852/852 [21:37<00:00,  1.52s/it, total=0.456, cls=0.253, box=0.177, obj=0.019]
# Val Epoch 0: 100% 213/213 [02:14<00:00,  1.58it/s, total=0.387, cls=0.215, box=0.154, obj=0.015]
#
# --- Epoch 0 Results ---
# TRAIN:
#   loss_classifier: 0.2522
#   loss_box_reg: 0.1500
#   loss_objectness: 0.0251
#   loss_rpn_box_reg: 0.0040
#   loss_total: 0.4313
#
# VALIDATION:
#   loss_classifier: 0.2149
#   loss_box_reg: 0.1597
#   loss_objectness: 0.0147
#   loss_rpn_box_reg: 0.0034
#   loss_total: 0.3927
#
# ...
# Epoch 2/10
# ...

# %%
#!cp /content/ATR_SAR/models/faster_rcnn.pt /content/drive/MyDrive/PIE/FasterRCNN_ResNet_SOC50_results/results3
# !cp /content/ATR_SAR/models/faster_rcnn.pt /content/drive/MyDrive/PIE/FasterRCNN_ResNet_MSTAR_results3/

# %%
# !cp /content/ATR_SAR/outputs/train_results.json /content/drive/MyDrive/PIE/FasterRCNN_ResNet_MSTAR_results3/
