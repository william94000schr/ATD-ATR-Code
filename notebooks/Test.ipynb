# %%
from google.colab import userdata
your_key = userdata.get('PIE_Colab')

# %%
# !git clone https://{your_key}@github.com/william94000schr/ATR_SAR.git
# Out:
# Cloning into 'ATR_SAR'...
# remote: Enumerating objects: 468, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 468 (delta 3), reused 3 (delta 0), pack-reused 458 (from 1)
# Receiving objects: 100% (468/468), 2.90 MiB | 5.13 MiB/s, done.
# Resolving deltas: 100% (271/271), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#!cp /content/drive/MyDrive/Dataset/PIE/Détection_Coco_newClasses/SOC_50classes_coco.tar /content/
# !cp /content/drive/MyDrive/Dataset/PIE/Détection_Coco/SOC_40classes_coco.tar /content/
#!cp /content/drive/MyDrive/Dataset/PIE/MSTAR_coco.tar /content/
#!tar -xf /content/SOC_50classes_coco.tar -C /content/ATR_SAR/data/ --strip-components=1
# !tar -xf /content/SOC_40classes_coco.tar -C /content/ATR_SAR/data/ --strip-components=1

# %%
#!cp /content/drive/MyDrive/PIE/FasterRCNN_ResNet_SOC50_results/faster_rcnn.pt /content/ATR_SAR/models
#!cp /content/drive/MyDrive/PIE/Faster_RCNN_SOC40classes_results/faster_rcnn.pt /content/ATR_SAR/models
#!cp /content/drive/MyDrive/PIE/Faster_MobileNet_SOC50Class_results/faster_rcnn.pt /content/ATR_SAR/models
# !cp /content/drive/MyDrive/PIE/SOC40classes_0_35_3sur5/faster_rcnn.pt /content/ATR_SAR/models

# %%
# %cd ATR_SAR/src/
# Out:
# /content/ATR_SAR/src

# %%
# !pip install torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 26.5 MB/s eta 0:00:00
# ...

# %%
# !python validation.py \
  --num_classes 40 \
  --proportion 1.0
# Out:
# loading annotations into memory...
# Done (t=0.11s)
# creating index...
# index created!
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_v2_coco-dd69338a.pth
# 100% 167M/167M [00:00<00:00, 195MB/s]
# 100% 1831/1831 [22:43<00:00,  1.34it/s]
# {'map': tensor(0.1855), 'map_50': tensor(0.3483), 'map_75': tensor(0.1753), 'map_small': tensor(0.0657), 'map_medium': tensor(0.1856), 'map_large': tensor(0.2864), 'mar_1': tensor(0.4885), 'mar_10': tensor(0.4892), 'mar_100': tensor(0.4892), 'mar_small': tensor(0.2491), 'mar_medium': tensor(0.4977), 'mar_large': tensor(0.3542), 'map_per_class': tensor([0.0835, 0.1358, 0.0392, 0.0362, 0.1052, 0.0614, 0.0385, 0.0191, 0.0484,
#         0.0915, 0.0447, 0.1029, 0.0346, 0.0444, 0.0284, 0.0798, 0.0794, 0.1834,
#         0.1454, 0.2195, 0.4791, 0.1348, 0.0973, 0.1070, 0.2058, 0.2679, 0.4017,
# ...

# %%
#!cp /content/ATR_SAR/outputs/test_results.json /content/drive/MyDrive/PIE/Faster_RCNN_SOC40classes_results/results2
# !cp /content/ATR_SAR/outputs/test_results.json /content/drive/MyDrive/PIE/SOC40classes_0_35_3sur5/
